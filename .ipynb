# %%
#to get the tool in the library for the plotting visualisation
import matplotlib.pyplot as plt

#making a list/array
x = [5, 2, 3, 4]
y = [1, 7, 4, 3]
x2 = [1, 2, 3, 4]
y2 = [4, 3, 2, 1]

#to plot a graph and show it
plt.plot(x, y, label = 'graph')
plt.plot(x2, y2, label = 'graph2')
plt.show()
